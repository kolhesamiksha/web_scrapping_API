# %% [markdown]
# # <font color='indigo'> **Best YouTube Channel To Learn Data Science from 2009**

# %%
'''
Krish naik: UCNU_lfiiWBdtULKOw6X0Dig
3B1B youtube channel: UCYO_jab_esuFRV4b17AJtAw
Ken jee: UCiT9RITQ9PW6BhXK0y2jaeg
david robinson: UCeiiqmVK07qhY-wvg3IZiZQ
Julia Silge: UCTTBgWyJl2HrrhQOOc710kA
Data Professor: UCV8e2g4IWQqK71bbzGDEI4Q
Freecodecamp.org : UC8butISFwT-Wl7EV0hUK0BQ
3blue1Brown: UCYO_jab_esuFRV4b17AJtAw
Sentdex: UCfzlCWGWYyIQ0aLC5w48gBQ
Codebasics: UCh9nVJoWXmFb7sLApWGcLPQ
Abhishek thakur: UCBPRJjIWfyNG4X-CRbnv78A
Statsquest: UCtYLUTtgS3k1Fg4y5tAhLbw
CampusX: UCCWi3hpnq_Pe03nGxuS7isg
'''
# Out:
# '\nKrish naik: UCNU_lfiiWBdtULKOw6X0Dig\n3B1B youtube channel: UCYO_jab_esuFRV4b17AJtAw\nKen jee: UCiT9RITQ9PW6BhXK0y2jaeg\ndavid robinson: UCeiiqmVK07qhY-wvg3IZiZQ\nJulia Silge: UCTTBgWyJl2HrrhQOOc710kA\nData Professor: UCV8e2g4IWQqK71bbzGDEI4Q\nFreecodecamp.org : UC8butISFwT-Wl7EV0hUK0BQ\n3blue1Brown: UCYO_jab_esuFRV4b17AJtAw\nSentdex: UCfzlCWGWYyIQ0aLC5w48gBQ\nCodebasics: UCh9nVJoWXmFb7sLApWGcLPQ\nAbhishek thakur: UCBPRJjIWfyNG4X-CRbnv78A\nStatsquest: UCtYLUTtgS3k1Fg4y5tAhLbw\nCampusX: UCCWi3hpnq_Pe03nGxuS7isg\n'

# %% [markdown]
# ## <font color='redorange'> **Data Aquisition from Youtube API**

# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
api_key = 'AIzaSyDm1e_N9LIwRt3W4zR8iBW9n4v_goyTbYQ'
channel_id = ['UCNU_lfiiWBdtULKOw6X0Dig',
              'UCYO_jab_esuFRV4b17AJtAw',
              'UCiT9RITQ9PW6BhXK0y2jaeg',
              'UCeiiqmVK07qhY-wvg3IZiZQ',
              'UCTTBgWyJl2HrrhQOOc710kA',
              'UCV8e2g4IWQqK71bbzGDEI4Q',
              'UC8butISFwT-Wl7EV0hUK0BQ',
              'UCYO_jab_esuFRV4b17AJtAw',
              'UCfzlCWGWYyIQ0aLC5w48gBQ',
              'UCh9nVJoWXmFb7sLApWGcLPQ',
              'UCBPRJjIWfyNG4X-CRbnv78A',
              'UCtYLUTtgS3k1Fg4y5tAhLbw',
              'UCCWi3hpnq_Pe03nGxuS7isg'
              ]

# %%
youtube = build('youtube','v3',developerKey=api_key)

# %%
request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_id)
    )
response = request.execute()
youtube_data = []
for i in range(len(response['items'])):
  data = dict(channel_name = response['items'][i]['snippet']['title'],
              description = response['items'][i]['snippet']['description'],
              published_date = response['items'][i]['snippet']['publishedAt'],
              total_views = response['items'][i]['statistics']['viewCount'],
              total_subscribers = response['items'][i]['statistics']['subscriberCount'],
              total_videos = response['items'][i]['statistics']['videoCount'],
              playlist_ids = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
  youtube_data.append(data)

print(data)
# Out:
# {'channel_name': 'CampusX', 'description': 'CampusX is an online mentorship program for engineering students. We offer a 6-month long mentorship to students in latest cutting - edge technologies like Machine Learning & Data Science, Full Stack Web Development and Mobile App Development.\n\n            At its core, CampusX aims to change this education system of India. We believe that high-quality education is not just for the privileged few. It is the right of everyone who seeks it. Through our mentorship program, we aim to bring quality education to every single student. A mentored student is provided with guidance on how to ace a technology through 24x7 mentorship, live and recorded video lectures, daily skill-building activities, project assignments, and evaluation, hackathons, interactions with industry experts, soft skill training, personal counseling, and comprehensive reports. All we need from you is intent, a ray of passion to learn.', 'published_date': '2019-04-17T19:32:35Z', 'total_views': '3212123', 'total_subscribers': '40600', 'total_videos': '904', 'playlist_ids': 'UUCWi3hpnq_Pe03nGxuS7isg'}

# %% [markdown]
# ### Analyzed the json output of response instance using jsonFormatter then added imp data as features

# %%
channels_data = pd.DataFrame(youtube_data)
channels_data
# Out:
#                    channel_name  \
# 0              freeCodeCamp.org
# 1                   3Blue1Brown
# 2   StatQuest with Josh Starmer
# 3                David Robinson
# 4                       Ken Jee
# 5                    Krish Naik
# 6                Data Professor
# 7                       sentdex
# 8                    codebasics
# 9               Abhishek Thakur
# 10                  Julia Silge
# 11                      CampusX
#
#                                           description        published_date  \
# 0                             Learn to code for free.  2014-12-16T21:18:48Z
# 1   3Blue1Brown, by Grant Sanderson, is some combi...  2015-03-03T23:11:55Z
# 2   Statistics, Machine Learning and Data Science ...  2011-05-24T01:52:48Z
# 3                                                      2007-07-22T04:33:32Z
# 4   Data Science and Sports Analytics are my passi...  2014-02-28T14:58:24Z
# 5   I am the cofounder of iNeuron and my experienc...  2012-02-11T04:05:06Z
# 6   Data Science, Machine Learning, Bioinformatics...  2019-08-17T15:59:56Z
# 7   Python Programming tutorials, going further th...  2012-12-16T20:49:11Z
# 8   I am Dhaval Patel, Founder of ed-tech platform...  2015-11-07T17:29:46Z
# 9   I make videos about applied machine learning, ...  2009-05-24T11:41:32Z
# 10                                                     2011-10-13T23:18:24Z
# 11  CampusX is an online mentorship program for en...  2019-04-17T19:32:35Z
#
#    total_views total_subscribers total_videos              playlist_ids
# 0    424942742           6300000         1351  UU8butISFwT-Wl7EV0hUK0BQ
# 1    299799145           4700000          124  UUYO_jab_esuFRV4b17AJtAw
# 2     40897198            798000          221  UUtYLUTtgS3k1Fg4y5tAhLbw
# 3       410823             14400          115  UUeiiqmVK07qhY-wvg3IZiZQ
# 4      6922811            218000          238  UUiT9RITQ9PW6BhXK0y2jaeg
# 5     61775251            655000         1497  UUNU_lfiiWBdtULKOw6X0Dig
# 6      3484558            134000          293  UUV8e2g4IWQqK71bbzGDEI4Q
# 7    104689665           1160000         1255  UUfzlCWGWYyIQ0aLC5w48gBQ
# 8     43854263            662000          560  UUh9nVJoWXmFb7sLApWGcLPQ
# 9      1999853             75100          148  UUBPRJjIWfyNG4X-CRbnv78A
# 10      368887             11800           61  UUTTBgWyJl2HrrhQOOc710kA
# 11     3212123             40600          904  UUCWi3hpnq_Pe03nGxuS7isg

# %%
channels_data.to_csv('Data_science_channels.csv')

# %%
list1 = []
for i in range(channels_data.shape[0]):
  playlist_id = channels_data['playlist_ids'][i]
  list1.append(playlist_id)

# %%
playlist_id = list1

# %% [markdown]
# ### Youtube Playlist and video details of Each and every youtuber can be obtained by their playlist id's

# %%
playlist_data = []
requestv = youtube.playlistItems().list(
        part='contentDetails',
        playlistId= list1[8]
    )
responsev = requestv.execute()

video_ids = []
    
for i in range(len(responsev['items'])):
    video_ids.append(responsev['items'][i]['contentDetails']['videoId'])
        
next_page_token = responsev.get('nextPageToken')
more_pages = True
    
while more_pages:
    if next_page_token is None:
        more_pages = False
    else:
        requestv = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = list1[8],
                    maxResults = 10,
                    pageToken = next_page_token)
        responsev = requestv.execute()
    
        for i in range(len(responsev['items'])):
            video_ids.append(responsev['items'][i]['contentDetails']['videoId'])
            
        next_page_token = responsev.get('nextPageToken')

# %%
all_video_stats = []
    
for i in range(0, len(video_ids), 50):
    requestn = youtube.videos().list(
              part='snippet,statistics',
              id=','.join(video_ids[i:i+50]))
    responsen = requestn.execute()
        
    for video in responsen['items']:
        video_stats = dict(Title = video['snippet']['title'],
                            Published_date = video['snippet']['publishedAt'],
                            Views = video['statistics']['viewCount'],
                            )
        all_video_stats.append(video_stats)

# %%
video_data = pd.DataFrame(all_video_stats)

# %%
video_data
# Out:
#                                                  Title        Published_date  \
# 0    Build Your Data Project Portfolio With Codebas...  2022-09-21T13:00:11Z
# 1         3 Important things to get your resume picked  2022-09-19T13:30:22Z
# 2    Three excellent websites to practice SQL inter...  2022-09-17T15:00:04Z
# 3    NVIDIA GPU Giveaway | World's Biggest FREE AI ...  2022-09-16T14:00:10Z
# 4    Build a Stand-Out Data Science Project Portfol...  2022-09-14T14:02:22Z
# ..                                                 ...                   ...
# 556                         Python Tutorial - 5. Lists  2015-12-20T23:01:51Z
# 557                       Python Tutorial - 4. Strings  2015-12-20T22:34:19Z
# 558                       Python Tutorial - 3. Numbers  2015-12-20T02:54:56Z
# 559                     Python Tutorial - 2. Variables  2015-12-20T02:11:10Z
# 560     Python Tutorial - 1. Install python on windows  2015-12-20T01:21:07Z
#
#      Views
# 0     4198
# 1     1601
# 2     2819
# 3     4439
# 4    23470
# ..     ...
# 556  32312
# 557  28184
# 558  31734
# 559  41773
# 560  46682
#
# [561 rows x 3 columns]

# %%
video_data.to_csv('3B1B_data.csv')

# %% [markdown]
# #<font color='RedOrange'> **Data Analysis**
#
#
#
#
# ```
# the data of Most watched data science channels on youtube is collected and now it's time to go for choosing the bestest among all🤩
# ```

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/Data_science_channels.csv')
data.head(10)
# Out:
#    Unnamed: 0                 channel_name  \
# 0           0             freeCodeCamp.org
# 1           1                  3Blue1Brown
# 2           2  StatQuest with Josh Starmer
# 3           3               David Robinson
# 4           4                      Ken Jee
# 5           5                   Krish Naik
# 6           6               Data Professor
# 7           7                      sentdex
# 8           8                   codebasics
# 9           9              Abhishek Thakur
#
#                                          description        published_date  \
# 0                            Learn to code for free.  2014-12-16T21:18:48Z
# 1  3Blue1Brown, by Grant Sanderson, is some combi...  2015-03-03T23:11:55Z
# 2  Statistics, Machine Learning and Data Science ...  2011-05-24T01:52:48Z
# 3                                                NaN  2007-07-22T04:33:32Z
# 4  Data Science and Sports Analytics are my passi...  2014-02-28T14:58:24Z
# 5  I am the cofounder of iNeuron and my experienc...  2012-02-11T04:05:06Z
# 6  Data Science, Machine Learning, Bioinformatics...  2019-08-17T15:59:56Z
# 7  Python Programming tutorials, going further th...  2012-12-16T20:49:11Z
# 8  I am Dhaval Patel, Founder of ed-tech platform...  2015-11-07T17:29:46Z
# 9  I make videos about applied machine learning, ...  2009-05-24T11:41:32Z
#
#    total_views  total_subscribers  total_videos              playlist_ids
# 0    424942742            6300000          1351  UU8butISFwT-Wl7EV0hUK0BQ
# 1    299799145            4700000           124  UUYO_jab_esuFRV4b17AJtAw
# 2     40897198             798000           221  UUtYLUTtgS3k1Fg4y5tAhLbw
# 3       410823              14400           115  UUeiiqmVK07qhY-wvg3IZiZQ
# 4      6922811             218000           238  UUiT9RITQ9PW6BhXK0y2jaeg
# 5     61775251             655000          1497  UUNU_lfiiWBdtULKOw6X0Dig
# 6      3484558             134000           293  UUV8e2g4IWQqK71bbzGDEI4Q
# 7    104689665            1160000          1255  UUfzlCWGWYyIQ0aLC5w48gBQ
# 8     43854263             662000           560  UUh9nVJoWXmFb7sLApWGcLPQ
# 9      1999853              75100           148  UUBPRJjIWfyNG4X-CRbnv78A

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
import warnings
import re

# %%
sort_subs_data = data.sort_values('total_subscribers',ascending=False)
sort_views_data = data.sort_values('total_views',ascending=False)
sort_videos_data = data.sort_values('total_videos',ascending=False)

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sb.barplot(sort_subs_data['total_subscribers'],sort_subs_data['channel_name'],palette="Blues_d",orient='horizontal')
plt.xlabel('Total Subscribers')
plt.ylabel('Channel_name')
plt.figure(figsize=(20,10))
plt.subplot(2,2,2)
sb.barplot(sort_views_data['total_views'],sort_views_data['channel_name'],palette="Blues_d",orient='horizontal')
plt.xlabel('Total views')
plt.ylabel('Channel_name')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Channel_name')

# %% [markdown]
# ### From the above we can see that the most popular data science youtube channel is
#
#
# ```
# 1. FreeCodeCamp.org
# 2. 3Blue1Brown
# 3. Sentdex
# 4. Statquest with Josh Stammer
# 5. Codebasics.
# ```
#
# ### But we can't measure their popularity by neglecting their year of starting their channels.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         12 non-null     int64
#  1   channel_name       12 non-null     object
#  2   description        10 non-null     object
#  3   published_date     12 non-null     object
#  4   total_views        12 non-null     int64
#  5   total_subscribers  12 non-null     int64
#  6   total_videos       12 non-null     int64
#  7   playlist_ids       12 non-null     object
# dtypes: int64(4), object(4)
# memory usage: 896.0+ bytes

# %%
data['Day'] = pd.to_datetime(data['published_date']).dt.day
data['Month'] = pd.to_datetime(data['published_date']).dt.month
data['Year'] = pd.to_datetime(data['published_date']).dt.year

# %%
data = data.drop('published_date',axis=1)

# %%
data
# Out:
#     Unnamed: 0                 channel_name  \
# 0            0             freeCodeCamp.org
# 1            1                  3Blue1Brown
# 2            2  StatQuest with Josh Starmer
# 3            3               David Robinson
# 4            4                      Ken Jee
# 5            5                   Krish Naik
# 6            6               Data Professor
# 7            7                      sentdex
# 8            8                   codebasics
# 9            9              Abhishek Thakur
# 10          10                  Julia Silge
# 11          11                      CampusX
#
#                                           description  total_views  \
# 0                             Learn to code for free.    424942742
# 1   3Blue1Brown, by Grant Sanderson, is some combi...    299799145
# 2   Statistics, Machine Learning and Data Science ...     40897198
# 3                                                 NaN       410823
# 4   Data Science and Sports Analytics are my passi...      6922811
# 5   I am the cofounder of iNeuron and my experienc...     61775251
# 6   Data Science, Machine Learning, Bioinformatics...      3484558
# 7   Python Programming tutorials, going further th...    104689665
# 8   I am Dhaval Patel, Founder of ed-tech platform...     43854263
# 9   I make videos about applied machine learning, ...      1999853
# 10                                                NaN       368887
# 11  CampusX is an online mentorship program for en...      3212123
#
#     total_subscribers  total_videos              playlist_ids  Day  Month  \
# 0             6300000          1351  UU8butISFwT-Wl7EV0hUK0BQ   16     12
# 1             4700000           124  UUYO_jab_esuFRV4b17AJtAw    3      3
# 2              798000           221  UUtYLUTtgS3k1Fg4y5tAhLbw   24      5
# 3               14400           115  UUeiiqmVK07qhY-wvg3IZiZQ   22      7
# 4              218000           238  UUiT9RITQ9PW6BhXK0y2jaeg   28      2
# 5              655000          1497  UUNU_lfiiWBdtULKOw6X0Dig   11      2
# 6              134000           293  UUV8e2g4IWQqK71bbzGDEI4Q   17      8
# 7             1160000          1255  UUfzlCWGWYyIQ0aLC5w48gBQ   16     12
# 8              662000           560  UUh9nVJoWXmFb7sLApWGcLPQ    7     11
# 9               75100           148  UUBPRJjIWfyNG4X-CRbnv78A   24      5
# 10              11800            61  UUTTBgWyJl2HrrhQOOc710kA   13     10
# 11              40600           904  UUCWi3hpnq_Pe03nGxuS7isg   17      4
#
#     Year
# 0   2014
# 1   2015
# 2   2011
# 3   2007
# 4   2014
# 5   2012
# 6   2019
# 7   2012
# 8   2015
# 9   2009
# 10  2011
# 11  2019

# %%
yt_groupby = data['total_subscribers'].groupby(data['Year'])

# %%
x = list(yt_groupby)
y = x[2][1].to_list()

# %%
ningth_youtubers = data[data['Year']==2009]

# %%
ningth_youtubers
# Out:
#    Unnamed: 0     channel_name  \
# 9           9  Abhishek Thakur
#
#                                          description  total_views  \
# 9  I make videos about applied machine learning, ...      1999853
#
#    total_subscribers  total_videos              playlist_ids  Day  Month  Year
# 9              75100           148  UUBPRJjIWfyNG4X-CRbnv78A   24      5  2009

# %% [markdown]
# ### Abhishekh thakur has started channel in 2019, so as per the statistics he should have the highest subscribers but that's not the case. So he is not more popular

# %%
eleventh_youtubers = data[data['Year']==2011]
eleventh_youtubers
# Out:
#     Unnamed: 0                 channel_name  \
# 2            2  StatQuest with Josh Starmer
# 10          10                  Julia Silge
#
#                                           description  total_views  \
# 2   Statistics, Machine Learning and Data Science ...     40897198
# 10                                                NaN       368887
#
#     total_subscribers  total_videos              playlist_ids  Day  Month  \
# 2              798000           221  UUtYLUTtgS3k1Fg4y5tAhLbw   24      5
# 10              11800            61  UUTTBgWyJl2HrrhQOOc710kA   13     10
#
#     Year
# 2   2011
# 10  2011

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sb.barplot(eleventh_youtubers['channel_name'],eleventh_youtubers['total_subscribers'])
plt.subplot(1,2,2)
sb.barplot(eleventh_youtubers['channel_name'],eleventh_youtubers['total_views'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Hence from 2011 youtubers Statquest with Josh Stammer won

# %%
twealth_youtubers = data[data['Year']==2012]
twealth_youtubers
# Out:
#    Unnamed: 0 channel_name                                        description  \
# 5           5   Krish Naik  I am the cofounder of iNeuron and my experienc...
# 7           7      sentdex  Python Programming tutorials, going further th...
#
#    total_views  total_subscribers  total_videos              playlist_ids  \
# 5     61775251             655000          1497  UUNU_lfiiWBdtULKOw6X0Dig
# 7    104689665            1160000          1255  UUfzlCWGWYyIQ0aLC5w48gBQ
#
#    Day  Month  Year
# 5   11      2  2012
# 7   16     12  2012

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sb.barplot(twealth_youtubers['channel_name'],twealth_youtubers['total_subscribers'])
plt.subplot(1,2,2)
sb.barplot(twealth_youtubers['channel_name'],twealth_youtubers['total_views'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### From 2011 Sentdex wins

# %%
compare_1 = data[data['channel_name']=='Krish Naik'].append(data[data['channel_name']=='StatQuest with Josh Starmer'])

# %%
compare_1
# Out:
#    Unnamed: 0                 channel_name  \
# 5           5                   Krish Naik
# 2           2  StatQuest with Josh Starmer
#
#                                          description  total_views  \
# 5  I am the cofounder of iNeuron and my experienc...     61775251
# 2  Statistics, Machine Learning and Data Science ...     40897198
#
#    total_subscribers  total_videos              playlist_ids  Day  Month  Year
# 5             655000          1497  UUNU_lfiiWBdtULKOw6X0Dig   11      2  2012
# 2             798000           221  UUtYLUTtgS3k1Fg4y5tAhLbw   24      5  2011

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sb.barplot(compare_1['channel_name'],compare_1['total_subscribers'])
plt.subplot(1,2,2)
sb.barplot(compare_1['channel_name'],compare_1['total_views'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Hence From the above data Statquest with Josh Starmer wins in terms of subscribers and in terms of viewers Krish Naik wins

# %%
compare_0 = data[data['channel_name']=='sentdex'].append(data[data['channel_name']=='StatQuest with Josh Starmer'])
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sb.barplot(compare_0['channel_name'],compare_0['total_subscribers'])
plt.subplot(1,2,2)
sb.barplot(compare_0['channel_name'],compare_0['total_views'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
forteen_youtubers = data[data['Year']==2014]
forteen_youtubers
# Out:
#    Unnamed: 0      channel_name  \
# 0           0  freeCodeCamp.org
# 4           4           Ken Jee
#
#                                          description  total_views  \
# 0                            Learn to code for free.    424942742
# 4  Data Science and Sports Analytics are my passi...      6922811
#
#    total_subscribers  total_videos              playlist_ids  Day  Month  Year
# 0            6300000          1351  UU8butISFwT-Wl7EV0hUK0BQ   16     12  2014
# 4             218000           238  UUiT9RITQ9PW6BhXK0y2jaeg   28      2  2014

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sb.barplot(forteen_youtubers['channel_name'],forteen_youtubers['total_subscribers'])
plt.subplot(1,2,2)
sb.barplot(forteen_youtubers['channel_name'],forteen_youtubers['total_views'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Its very clear from above that freeCodeCamp.org has more viewers and subscribers as well

# %%
compare_2 = data[data['channel_name']=='freeCodeCamp.org'].append(data[data['channel_name']=='sentdex'])
compare_3 = data[data['channel_name']=='Ken Jee'].append(data[data['channel_name']=='Krish Naik'])

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sb.barplot(compare_2['channel_name'],compare_2['total_subscribers'])
plt.subplot(1,2,2)
sb.barplot(compare_2['channel_name'],compare_2['total_views'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sb.barplot(compare_3['channel_name'],compare_3['total_subscribers'])
plt.subplot(1,2,2)
sb.barplot(compare_3['channel_name'],compare_3['total_views'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### FreeCodeCamp.org wins though started after statquest it could be because, people started focusing more on AI/Data Science

# %%
five_youtubers = data[data['Year']==2015]
five_youtubers
# Out:
#    Unnamed: 0 channel_name                                        description  \
# 1           1  3Blue1Brown  3Blue1Brown, by Grant Sanderson, is some combi...
# 8           8   codebasics  I am Dhaval Patel, Founder of ed-tech platform...
#
#    total_views  total_subscribers  total_videos              playlist_ids  \
# 1    299799145            4700000           124  UUYO_jab_esuFRV4b17AJtAw
# 8     43854263             662000           560  UUh9nVJoWXmFb7sLApWGcLPQ
#
#    Day  Month  Year
# 1    3      3  2015
# 8    7     11  2015

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sb.barplot(five_youtubers['channel_name'],five_youtubers['total_subscribers'])
plt.subplot(1,2,2)
sb.barplot(five_youtubers['channel_name'],five_youtubers['total_views'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
compare_4 = data[data['channel_name']=='freeCodeCamp.org'].append(data[data['channel_name']=='3Blue1Brown'])
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sb.barplot(compare_4['channel_name'],compare_4['total_subscribers'])
plt.subplot(1,2,2)
sb.barplot(compare_4['channel_name'],compare_4['total_views'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# sentdex has berformed much better & can be placed second highest

# %%
compare_5 = data[data['channel_name']=='sentdex'].append(data[data['channel_name']=='3Blue1Brown'])
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sb.barplot(compare_5['channel_name'],compare_5['total_subscribers'])
plt.subplot(1,2,2)
sb.barplot(compare_5['channel_name'],compare_5['total_views'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Though sentdex has started lately so it must have more subscribers but 3B1B outperformed

# %% [markdown]
# 1. Sentdex started in 2012
# 2. FreeCodeCamp.org started in 2014
# 2. 3Blue1brown started in 2015
#
# Subscribers&viewers of Sentdex< 3B1B <FreeCodeCamp
#
# Now let's compare with no of videos uploaded
# - assumption: More no of videos more popularity

# %%
compare_6 = data[data['channel_name']=='sentdex'].append(data[data['channel_name']=='3Blue1Brown'])
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sb.barplot(compare_6['channel_name'],compare_6['total_videos'])
plt.subplot(1,2,2)
sb.barplot(compare_6['channel_name'],compare_6['total_videos'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### BAM!!! Sentdex is older though it has less popularity + 3B1B has such an extent of less videos though more popularity
#
#
#
# ```
# 3B1B does outstanding work
#
# but... let's check with freeCodeCamp as well it's more popular than 3B1B obvious coz, started earlier
#
# Now let's finalize which is the best Youtube channel among above in Data Science Learning on Youtube
# ```

# %%
plt.figure(figsize=(20,10))
sb.barplot(sort_videos_data['total_videos'],sort_videos_data['channel_name'],palette="Blues_d",orient='horizontal')
plt.xlabel('Total videos')
plt.ylabel('Channel_name')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Channel_name')

# %% [markdown]
# ## <font color='Brown' > **3Blue1Brown won** :🤩
#
# ## Hence it's clear 3B1B is most popular and best Data Science Youtube channel on Youtube
#
# ### followed by FreeCodeCamp.org -> Sentdex -> Statquest with Josh Starmer -> Krish Naik

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/3B1B.csv')
data
# Out:
#      Unnamed: 0                                              Title  \
# 0             0        We want more online math exposition (SoME2)
# 1             1                            Olympiad level counting
# 2             2  Oh, wait, actually the best Wordle opener is n...
# 3             3            Solving Wordle using information theory
# 4             4       Alice, Bob, and the average shadow of a cube
# ..          ...                                                ...
# 118         118                  Euler's Formula and Graph Duality
# 119         119                           Circle Division Solution
# 120         120                           A Curious Pattern Indeed
# 121         121                               Euler's Formula Poem
# 122         122  e to the pi i, a nontraditional take (old vers...
#
#            Published_date    Views  Comments
# 0    2022-06-09T05:18:39Z   191540       509
# 1    2022-05-23T15:55:10Z  1070716      2288
# 2    2022-02-13T18:33:24Z  4768746      6395
# 3    2022-02-06T13:28:52Z  9177600      8601
# 4    2021-12-20T15:02:30Z  1813903      3477
# ..                    ...      ...       ...
# 118  2015-06-21T06:05:43Z   410281       331
# 119  2015-05-24T05:25:09Z   509694       669
# 120  2015-04-11T08:19:03Z   501330       203
# 121  2015-03-05T06:15:23Z   140167       139
# 122  2015-03-05T06:15:22Z  2477694      2069
#
# [123 rows x 5 columns]

# %% [markdown]
# ### Topic Modelling On 3B1B Youtube Channel

# %%
text = []
for i in data.Title:
  text.append(''.join(i))

text
# Out:
# ['We want more online math exposition (SoME2)',
#  'Olympiad level counting',
#  'Oh, wait, actually the best Wordle opener is not “crane”…',
#  'Solving Wordle using information theory',
#  'Alice, Bob, and the average shadow of a cube',
#  '2021 Summer of Math Exposition results',
#  'Beyond the Mandelbrot set, an intro to holomorphic dynamics',
#  "Newton's Fractal (which Newton knew nothing about)",
#  'The Summer of Math Exposition',
#  'A quick trick for computing eigenvalues | Chapter 15, Essence of linear algebra',
#  'How (and why) to raise e to the power of a matrix | DE6',
#  "The medical test paradox, and redesigning Bayes' rule",
#  'Hamming codes part 2, the elegance of it all',
#  'How to send a self-correcting message (Hamming codes)',
#  'Group theory, abstraction, and the 196,883-dimensional monster',
#  'The impossible chessboard puzzle',
#  'Tips to be a better problem solver [Last live lecture] | Ep. 10 Lockdown live math',
#  'Intuition for i to the power i | Ep. 9 Lockdown live math',
#  'The DP-3T algorithm for contact tracing (via Nicky Case)',
#  'The power tower puzzle | Ep. 8 Lockdown live math',
#  'What makes the natural log "natural"? | Ep. 7 Lockdown live math',
#  'Logarithm Fundamentals | Ep. 6 Lockdown live math',
#  'Imaginary interest rates | Ep. 5 Lockdown live math',
#  "What is Euler's formula actually saying? | Ep. 4 Lockdown live math",
#  'Complex number fundamentals | Ep. 3 Lockdown live math',
#  'Trigonometry fundamentals | Ep. 2 Lockdown live math',
#  'The simpler quadratic formula | Ep. 1 Lockdown live math',
#  'Lockdown math announcement',
#  'Why “probability of 0” does not mean “impossible” | Probabilities of probabilities, part 2',
#  'Simulating an epidemic',
#  'Binomial distributions | Probabilities of probabilities, part 1',
#  'Exponential growth and epidemics',
#  "The quick proof of Bayes' theorem",
#  'Bayes theorem, the geometry of changing beliefs',
#  'Q&A with Grant (3blue1brown), windy walk edition',
#  'Why do prime numbers make these spirals? | Dirichlet’s theorem, pi approximations, and more',
#  'The unexpectedly hard windmill question (2011 IMO, Q2)',
#  'e^(iπ) in 3.14 minutes, using dynamics | DE5',
#  'Pure Fourier series animation montage',
#  'But what is a Fourier series?  From heat flow to drawing with circles | DE4',
#  'Solving the heat equation | DE3',
#  'But what is a partial differential equation?  | DE2',
#  "Differential equations, a tourist's guide | DE1",
#  "Cramer's rule, explained geometrically | Chapter 12, Essence of linear algebra",
#  'How colliding blocks act like a beam of light...to compute pi.',
#  'Why do colliding blocks compute pi?',
#  'The most unexpected answer to a counting puzzle',
#  "But why is a sphere's surface area four times its shadow?",
#  'Using topology to solve a counting riddle | The Borsuk-Ulam theorem and stolen necklaces',
#  'Why 5/3 is a fundamental constant for turbulence',
#  'Quaternions and 3d rotation, explained interactively',
#  'Visualizing quaternions (4d numbers) with stereographic projection',
#  'Q&A with Grant Sanderson (3blue1brown)',
#  'Why slicing a cone gives an ellipse',
#  "Other math channels you'd enjoy",
#  "Divergence and curl:  The language of Maxwell's equations, fluid flow, and more",
#  'The other way to visualize derivatives | Chapter 12, Essence of calculus',
#  'The Wallis product for pi, proved geometrically',
#  'Winding numbers and domain coloring',
#  'How pi was almost 6.283185...',
#  'Why is pi here?  And why is it squared?  A geometric answer to the Basel problem',
#  'The more general uncertainty principle, regarding Fourier transforms',
#  'But what is the Fourier Transform?  A visual introduction.',
#  'Why this puzzle is impossible',
#  'Q&A #2 + Net Neutrality Nuance',
#  'The hardest problem on the hardest test',
#  'Backpropagation calculus | Chapter 4, Deep learning',
#  'What is backpropagation really doing? | Chapter 3, Deep learning',
#  'Gradient descent, how neural networks learn | Chapter 2, Deep learning',
#  'But what is a neural network? | Chapter 1, Deep learning',
#  'Some light quantum mechanics (with minutephysics)',
#  'Thinking outside the 10-dimensional box',
#  "Hilbert's Curve: Is infinite math useful?",
#  'How secure is 256 bit security?',
#  'But how does bitcoin actually work?',
#  'All possible pythagorean triples, visualized',
#  'Pi hiding in prime regularities',
#  'Taylor series | Chapter 11, Essence of calculus',
#  'Higher order derivatives | Chapter 10, Essence of calculus',
#  'What does area have to do with slope? | Chapter 9, Essence of calculus',
#  'Integration and the fundamental theorem of calculus | Chapter 8, Essence of calculus',
#  "Limits, L'Hôpital's rule, and epsilon delta definitions | Chapter 7, Essence of calculus",
#  "Implicit differentiation, what's going on here? | Chapter 6, Essence of calculus",
#  "What's so special about Euler's number e? | Chapter 5, Essence of calculus",
#  'Visualizing the chain rule and product rule | Chapter 4, Essence of calculus',
#  'Derivative formulas through geometry | Chapter 3, Essence of calculus',
#  'The paradox of the derivative | Chapter 2, Essence of calculus',
#  'The essence of calculus',
#  "Euler's formula with introductory group theory",
#  'Fractals are typically not self-similar',
#  'Tattoos on Math',
#  'Visualizing the Riemann zeta function and analytic continuation',
#  'Binary, Hanoi, and Sierpinski, part 2',
#  'Binary, Hanoi and Sierpinski, part 1',
#  '3blue1brown channel trailer',
#  'Who cares about topology?   (Inscribed rectangle problem)',
#  'Abstract vector spaces | Chapter 16, Essence of linear algebra',
#  'Eigenvectors and eigenvalues | Chapter 14, Essence of linear algebra',
#  'Change of basis | Chapter 13, Essence of linear algebra',
#  'Cross products in the light of linear transformations | Chapter 11, Essence of linear algebra',
#  'Cross products | Chapter 10, Essence of linear algebra',
#  'Dot products and duality | Chapter 9, Essence of linear algebra',
#  'Nonsquare matrices as transformations between dimensions | Chapter 8, Essence of linear algebra',
#  'Inverse matrices, column space and null space | Chapter 7, Essence of linear algebra',
#  'The determinant | Chapter 6, Essence of linear algebra',
#  'Three-dimensional linear transformations | Chapter 5, Essence of linear algebra',
#  'Matrix multiplication as composition | Chapter 4, Essence of linear algebra',
#  'Linear transformations and matrices | Chapter 3, Essence of linear algebra',
#  'Linear combinations, span, and basis vectors | Chapter 2, Essence of linear algebra',
#  'Vectors | Chapter 1, Essence of linear algebra',
#  'Essence of linear algebra preview',
#  'Triangle of Power',
#  'The Brachistochrone, with Steven Strogatz',
#  "Snell's law proof using springs",
#  'Fractal charm: Space filling curves',
#  'Music And Measure Theory',
#  'How to count to 1000 on two hands',
#  'What does it feel like to invent math?',
#  "Euler's Formula and Graph Duality",
#  'Circle Division Solution',
#  'A Curious Pattern Indeed',
#  "Euler's Formula Poem",
#  'e to the pi i, a nontraditional take (old version)']

# %%
data['Title'] = data['Title'].apply(lambda x:re.sub("[?|().]","",x))

# %%
data['Title'] = data['Title'].apply(lambda x:re.sub(r"[0-9[]/]","",x))

# %%
data
# Out:
#      Unnamed: 0                                              Title  \
# 0             0          We want more online math exposition SoME2
# 1             1                            Olympiad level counting
# 2             2  Oh, wait, actually the best Wordle opener is n...
# 3             3            Solving Wordle using information theory
# 4             4       Alice, Bob, and the average shadow of a cube
# ..          ...                                                ...
# 118         118                  Euler's Formula and Graph Duality
# 119         119                           Circle Division Solution
# 120         120                           A Curious Pattern Indeed
# 121         121                               Euler's Formula Poem
# 122         122   e to the pi i, a nontraditional take old version
#
#            Published_date    Views  Comments
# 0    2022-06-09T05:18:39Z   191540       509
# 1    2022-05-23T15:55:10Z  1070716      2288
# 2    2022-02-13T18:33:24Z  4768746      6395
# 3    2022-02-06T13:28:52Z  9177600      8601
# 4    2021-12-20T15:02:30Z  1813903      3477
# ..                    ...      ...       ...
# 118  2015-06-21T06:05:43Z   410281       331
# 119  2015-05-24T05:25:09Z   509694       669
# 120  2015-04-11T08:19:03Z   501330       203
# 121  2015-03-05T06:15:23Z   140167       139
# 122  2015-03-05T06:15:22Z  2477694      2069
#
# [123 rows x 5 columns]

# %%
data['Title'] = data['Title'].apply(lambda x:re.sub(r"[,...]","",x))

# %%
data
# Out:
#      Unnamed: 0                                              Title  \
# 0             0          We want more online math exposition SoME2
# 1             1                            Olympiad level counting
# 2             2  Oh wait actually the best Wordle opener is not...
# 3             3            Solving Wordle using information theory
# 4             4         Alice Bob and the average shadow of a cube
# ..          ...                                                ...
# 118         118                  Euler's Formula and Graph Duality
# 119         119                           Circle Division Solution
# 120         120                           A Curious Pattern Indeed
# 121         121                               Euler's Formula Poem
# 122         122    e to the pi i a nontraditional take old version
#
#            Published_date    Views  Comments
# 0    2022-06-09T05:18:39Z   191540       509
# 1    2022-05-23T15:55:10Z  1070716      2288
# 2    2022-02-13T18:33:24Z  4768746      6395
# 3    2022-02-06T13:28:52Z  9177600      8601
# 4    2021-12-20T15:02:30Z  1813903      3477
# ..                    ...      ...       ...
# 118  2015-06-21T06:05:43Z   410281       331
# 119  2015-05-24T05:25:09Z   509694       669
# 120  2015-04-11T08:19:03Z   501330       203
# 121  2015-03-05T06:15:23Z   140167       139
# 122  2015-03-05T06:15:22Z  2477694      2069
#
# [123 rows x 5 columns]

# %%
# !pip install bertopic[gensim]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bertopic[gensim] in /usr/local/lib/python3.7/dist-packages (0.12.0)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.7/dist-packages (from bertopic[gensim]) (5.5.0)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from bertopic[gensim]) (1.3.5)
# Requirement already satisfied: hdbscan>=0.8.28 in /usr/local/lib/python3.7/dist-packages (from bertopic[gensim]) (0.8.28)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from bertopic[gensim]) (1.21.6)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from bertopic[gensim]) (2.2.2)
# Requirement already satisfied: pyyaml<6.0 in /usr/local/lib/python3.7/dist-packages (from bertopic[gensim]) (5.4.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from bertopic[gensim]) (0.5.3)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.7/dist-packages (from bertopic[gensim]) (4.64.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.7/dist-packages (from bertopic[gensim]) (1.0.2)
# Collecting gensim>=4.0.0
#   Downloading gensim-4.2.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.1 MB)
#      |████████████████████████████████| 24.1 MB 2.1 MB/s
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim>=4.0.0->bertopic[gensim]) (1.7.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim>=4.0.0->bertopic[gensim]) (5.2.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic[gensim]) (1.1.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic[gensim]) (0.29.32)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic[gensim]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic[gensim]) (2022.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic[gensim]) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic[gensim]) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2.post1->bertopic[gensim]) (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic[gensim]) (4.22.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic[gensim]) (3.7)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic[gensim]) (0.1.97)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic[gensim]) (0.9.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic[gensim]) (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic[gensim]) (0.13.1+cu113)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[gensim]) (2.23.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[gensim]) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[gensim]) (3.8.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[gensim]) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[gensim]) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[gensim]) (3.0.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[gensim]) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[gensim]) (2022.6.2)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.5.0->bertopic[gensim]) (0.5.7)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.5.0->bertopic[gensim]) (0.56.2)
# Requirement already satisfied: setuptools<60 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[gensim]) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[gensim]) (0.39.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[gensim]) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic[gensim]) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[gensim]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[gensim]) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[gensim]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[gensim]) (2.10)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[gensim]) (7.1.2)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-4.2.0

# %%
from bertopic import BERTopic

# %%
topic_model = BERTopic()
topics, probs = topic_model.fit_transform(data['Title'])

# %%
d_frame = topic_model.get_topic_info()
d_frame
# Out:
#    Topic  Count                         Name
# 0      0    106            0_the_of_and_math
# 1      1     17  1_linear_algebra_essence_of

# %%
topic = d_frame.iloc[1]['Topic']
topic_model.get_topic(topic)
# Out:
# [('linear', 0.41659892972062873),
#  ('algebra', 0.35920777206771387),
#  ('essence', 0.30411283109571896),
#  ('of', 0.2882625154788255),
#  ('chapter', 0.2798501349469989),
#  ('transformations', 0.12066747639221645),
#  ('products', 0.09595576682069121),
#  ('matrices', 0.09595576682069121),
#  ('and', 0.09390575369490893),
#  ('vectors', 0.06910764353479494)]

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f52abbff-f0dd-4746-94bf-1730d5423224" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f52abbff-f0dd-4746-94bf-1730d5423224")) {                    Plotly.newPlot(                        "f52abbff-f0dd-4746-94bf-1730d5423224",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.07221132777920568,0.07850601184831939,0.07884065951925509,0.08597979194446531,0.12528964147272773],"y":["to  ","math  ","and  ","of  ","the  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.2798501349469989,0.2882625154788255,0.30411283109571896,0.35920777206771387,0.41659892972062873],"y":["chapter  ","of  ","essence  ","algebra  ","linear  "],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}]," ...

# %%
topic_model.get_topic(0)
# Out:
#    Topic  Count               Name
# 0      0    106  0_the_of_and_math

# %%
topic_model.get_topic_info(0)
# Out:
#    Topic  Count               Name
# 0      0    106  0_the_of_and_math

# %%
topic_model.find_topics('transformations')
# Out:
# ([1, 0], [0.5474076165214796, 0.3826473237973273])

# %%
from sentence_transformers import SentenceTransformer

# %%
sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = sentence_model.encode(data['Title'], show_progress_bar=False)

# %%
topic_model = BERTopic().fit(data['Title'], embeddings)

# %%
topic_model.visualize_documents(data['Title'], embeddings=embeddings)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="395a6645-7d2a-4b33-a7cd-e21f518280a5" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("395a6645-7d2a-4b33-a7cd-e21f518280a5")) {                    Plotly.newPlot(                        "395a6645-7d2a-4b33-a7cd-e21f518280a5",                        [{"hoverinfo":"text","hovertext":[null],"marker":{"color":"#CFD8DC","opacity":0.5,"size":5},"mode":"markers+text","name":"other","showlegend":false,"x":[null],"y":[null],"type":"scattergl"},{"hoverinfo":"text","hovertext":["Hilbert's Curve: Is infinite math useful","Differential equations a tourist's guide  DE1","What's so special about Euler's number e  Chapter 5 Essence of calculus","But what is a partial differential equation   DE2","Hamming codes part 2 the elegance of it all","Solving Wordle using information theory","Binary Hanoi and Sierpinski part 1","All possible pythagorean triples visualized","Taylor series  Chapter 11 Essence of calculus","The most unexpected answer to a counting puzzle","How and why to raise e to the power of a matrix  DE6","Visualizing the Riemann zeta function and analytic continuation","But what is a neural network  Chapter 1 Deep learning","Simulating an epidemic","Why \u201cprobability of 0\u201d does not mean \u201cimpossible\u201d  Probabilities of probabilities part 2","Higher order derivatives  Chapter 10 Essence of calculus","How colliding blocks act like a beam of lightto compute pi","Binary Hanoi and Sierpinski part 2","Newton's Fractal which Newton knew nothing about","Circle Division Solution","The impossible chessboard puzzle","Why 5/3 is a fundamental constant for turbulence","Complex number fundamentals  Ep 3 Lockdown live math","Q&A #2 + Net Neutrality Nuance","What does it feel like to invent math","The paradox of the derivative  Chapter 2 Essence of calculus","Why do prime numbers make these spirals  Dirichlet\u2019s theorem pi approximations and more","Solving the heat equation  DE3","Music And Measure Theory","We want more online math exposition SoME2","How pi was almost 6283185","The hardest problem on the hardest test","Derivative formulas through geometry  Chapter 3 Essence of calculus","Other math channels you'd enjoy","What is Euler's formula actually saying  Ep 4 Lockdown live math","The power tower puzzle  Ep 8 Lockdown live math","The essence of calculus","Oh wait actually the best Wordle opener is not \u201ccrane\u201d\u2026","Lockdown math announcement","Why do colliding blocks compute pi","Q&A with Grant Sanderson 3blue1brown","Tattoos on Math","Snell's law proof using springs","Divergence and curl:  The language of Maxwell's equations fluid flow and more","But how does bitcoin actually work","Winding numbers and domain coloring","Implicit differentiation what's going on here  Chapter 6 Essence of calculus","Pure Fourier series animation montage","Euler's Formula Poem","But why is a sphere's surface area four times its shadow","Why is pi here  And why is it squared  A geometric answer to the Basel problem","Fractals are typically not self-similar","The more general uncertainty principle regarding Fourier transforms","3blue1brown channel trailer","Logarithm Fundamentals  Ep 6 Lockdown live math","What makes the natural log \"natural\"  Ep 7 Lockdown live math","The Wallis product for pi proved geometrically","But what is a Fourier series  From heat flow to drawing with circles  DE4","e^i\u03c0 in 314 minutes using dynamics  DE5","Backpropagation calculus  Chapter 4 Deep learning","Using topology to solve a counting riddle  The Borsuk-Ulam theorem and stolen necklaces","The unexpectedly hard windmill question 2011 IMO Q2","Who cares about topology   Inscribed rectangle problem","A Curious Pattern Indeed","Trigonometry fundamental ...

# %% [markdown]
# #### Hence, **Topic Modelling Using BERT** successfully implemented on 3B1B Winner youtube channel video descriptions and generated 2 topics
#
# #### Concluded most of videos are maths,linear algebra,Machine learning related.
